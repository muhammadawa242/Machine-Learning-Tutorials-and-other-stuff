# %% [markdown]
# # Tutorial#1

# %%
import pandas as pd

df = pd.read_csv('data/survey_results_public.csv')
sdf = pd.read_csv('data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows',180)

# %%
df.shape
# Out:
# (73268, 79)

# %%
sdf.head(3)
# Out:
#      qid     qname                                           question  \
# 0  QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1  QID12  MetaInfo                                  Browser Meta Info
# 2   QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB

# %%
sdf.tail(3)
# Out:
#        qid        qname                                           question  \
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp type selector
# 76        NaN   MC     MAVR
# 77        NaN   MC     MAVR
# 78        NaN   MC     MAVR

# %% [markdown]
# # Tutorial#2

# %%
peeps = {
    'a' : [1,2,3],
    'b' : [4,5,6]
}

dp = pd.DataFrame(peeps)

# %%
dp['a'] # is a Series object (which is mainly just a one-dimensional array)
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
dp.columns
# Out:
# Index(['a', 'b'], dtype='object')

# %%
dp[['a','b']]   # returns another data frame
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dp.iloc[0]  # returns rows (iloc = searches by index location)
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
dp.iloc[[0,1]]
# Out:
#    a  b
# 0  1  4
# 1  2  5

# %%
dp.iloc[0,1]    #(row,column)
# Out:
# 4

# %%
dp.iloc[[0,1],1]    #for 2 rows
# Out:
# 0    4
# 1    5
# Name: b, dtype: int64

# %%
dp.loc[[0,1,2],'a'] #loc works same for rows but for columns, specify there column name
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %% [markdown]
# ### Using stack Overflows data

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
# France                                                   2328
# Brazil                                                   2109
# Poland                                                   1732
# Netherlands                                              1555
# Spain                                                    1521
# Italy                                                    1514
# Australia                                                1462
# Russian Federation                                       1229
# Turkey                                                   1020
# Sweden                                                   1020
# ...

# %%
df.loc[2]
# Out:
# ResponseId                                                                        3
# MainBranch                        I am not primarily a developer, but I write co...
# Employment                                                      Employed, full-time
# RemoteWork                                     Hybrid (some remote, some in-person)
# CodingActivities                                                              Hobby
# EdLevel                             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# LearnCode                         Books / Physical media;Friend or family member...
# LearnCodeOnline                   Technical documentation;Blogs;Programming Game...
# LearnCodeCoursesCert                                                            NaN
# YearsCode                                                                        14
# YearsCodePro                                                                      5
# ...

# %%
df.loc[55,'Country']
# Out:
# 'United States of America'

# %% [markdown]
# #### Slicing (It is inclusive for start and end both)

# %%
df.loc[0:4,'Country']   #same as df.loc[[0,1,2,3,4], 'Country']
# Out:
# 0                                                  NaN
# 1                                               Canada
# 2    United Kingdom of Great Britain and Northern I...
# 3                                               Israel
# 4                             United States of America
# Name: Country, dtype: object

# %%
df.loc[20:30,'Employment':'DevType']  #column slicing DAMN!
# Out:
#                                            Employment  \
# 20             Student, part-time;Employed, part-time
# 21                                Employed, full-time
# 22                                Employed, full-time
# 23                                Employed, full-time
# 24  Independent contractor, freelancer, or self-em...
# 25                                Employed, full-time
# 26                                Employed, full-time
# 27             Not employed, and not looking for work
# 28                                Employed, full-time
# 29  Employed, full-time;Independent contractor, fr...
# 30                                                NaN
#
#                               RemoteWork  \
# 20  Hybrid (some remote, some in-person)
# 21  Hybrid (some remote, some in-person)
# 22                          Fully remote
# 23  Hybrid (some remote, some in-person)
# 24                          Fully remote
# 25  Hybrid (some remote, some in-person)
# ...

# %% [markdown]
# # Tutorial#3

# %%
peeps2 = {
    'first':['awais','talha','saleh'],
    'last':['ahmad','mumtaz','jahanzaib'],
    'email':['awais123','talha123','saleh123']
}

dp2 = pd.DataFrame(peeps2)

# %%
dp2.set_index('email')  #sets index as email(chose this as email is unique)
# Out:
#           first       last
# email
# awais123  awais      ahmad
# talha123  talha     mumtaz
# saleh123  saleh  jahanzaib

# %%
dp2.set_index('email',inplace=True) #permanently sets email as index

# %%
dp2
# Out:
#           first       last
# email
# awais123  awais      ahmad
# talha123  talha     mumtaz
# saleh123  saleh  jahanzaib

# %%
dp2.reset_index(inplace=True)
dp2
# Out:
#       email  first       last
# 0  awais123  awais      ahmad
# 1  talha123  talha     mumtaz
# 2  saleh123  saleh  jahanzaib

# %% [markdown]
# ### Stack Overflow Exapmle

# %%
df.set_index('ResponseId',inplace=True) #can also do this from pd.read_csv(...,index_col='')
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
sdf.set_index('qname',inplace=True)
sdf.head()
# Out:
#                qid                                           question  \
# qname
# S0           QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo     QID12                                  Browser Meta Info
# S1            QID1  <span style="font-size:22px; font-family: aria...
# MainBranch    QID2  Which of the following options best describes ...
# Employment  QID296  Which of the following best describes your cur...
#
#            force_resp  type selector
# qname
# S0              False    DB       TB
# MetaInfo        False  Meta  Browser
# S1              False    DB       TB
# MainBranch       True    MC     SAVR
# Employment      False    MC     MAVR

# %%
sdf.loc['Employment','question']
# Out:
# 'Which of the following best describes your current employment status?'

# %%
sdf.sort_index()
# Out:
#                          qid  \
# qname
# Accessibility         QID124
# Age                   QID127
# Blockchain            QID305
# BuyNewTool            QID279
# CodingActivities      QID297
# CompFreq               QID52
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Ethnicity             QID126
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Gender                QID122
# ICorPM                QID287
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# Knowledge_5           QID289
# Knowledge_6           QID289
# Knowledge_7           QID289
# Language              QID233
# LearnCode             QID276
# ...

# %% [markdown]
# # Tutorial#4

# %%
filt = (dp2['last'] == 'ahmad') | (dp2['first'] == 'talha')   # and = & .... or = |
dp2[filt]
# Out:
#       email  first    last
# 0  awais123  awais   ahmad
# 1  talha123  talha  mumtaz

# %%
# Also this
dp2.loc[filt,'email']
# Out:
# 0    awais123
# 1    talha123
# Name: email, dtype: object

# %%
dp2.loc[~filt,'email']
# Out:
# 2    saleh123
# Name: email, dtype: object

# %%
sal = df['DevType'].str.contains('machine learning', na=False)
df.loc[sal]
# Out:
#                                                    MainBranch  \
# ResponseId
# 3           I am not primarily a developer, but I write co...
# 42                             I am a developer by profession
# 51          I am not primarily a developer, but I write co...
# 62                                I code primarily as a hobby
# 86                             I am a developer by profession
# ...                                                       ...
# 73197                          I am a developer by profession
# 73230                          I am a developer by profession
# 73235                          I am a developer by profession
# 73255       I am not primarily a developer, but I write co...
# 73265                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 3                                         Employed, full-time
# 42                                        Employed, full-time
# ...

# %%
sdf.loc['Knowledge_1']
# Out:
# qid                                                      QID289
# question      I have interactions with people outside of my ...
# force_resp                                                  NaN
# type                                                         MC
# selector                                                   MAVR
# Name: Knowledge_1, dtype: object

# %% [markdown]
# # Tutorial#5

# %%
dp2.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
dp2.columns = ['a','b','c']
dp2
# Out:
#           a      b          c
# 0  awais123  awais      ahmad
# 1  talha123  talha     mumtaz
# 2  saleh123  saleh  jahanzaib

# %%
dp2.columns = ['first', 'last', 'email']
dp2
# Out:
#       first   last      email
# 0  awais123  awais      ahmad
# 1  talha123  talha     mumtaz
# 2  saleh123  saleh  jahanzaib

# %%
dp2.rename(columns={                     #changes specified column names
    'first_name':'first',
    'last_name':'last'}, inplace=True)
dp2
# Out:
#       first   last      email
# 0  awais123  awais      ahmad
# 1  talha123  talha     mumtaz
# 2  saleh123  saleh  jahanzaib

# %%
dp2.loc[0,'first'] = 'sohaib'
dp2
# Out:
#       first   last      email
# 0    sohaib  awais      ahmad
# 1  talha123  talha     mumtaz
# 2  saleh123  saleh  jahanzaib

# %%
filt = (dp2['last'] == 'ahmad')
dp2.loc[filt,'first'] = 'awais'
dp2
# Out:
#       first   last      email
# 0    sohaib  awais      ahmad
# 1  talha123  talha     mumtaz
# 2  saleh123  saleh  jahanzaib

# %%
dp2['email'] = dp2['email'].str.upper()
dp2
# Out:
#       first   last      email
# 0    sohaib  awais      AHMAD
# 1  talha123  talha     MUMTAZ
# 2  saleh123  saleh  JAHANZAIB

# %% [markdown]
# > 4 ways to change multiplr rows:
# - apply
# - applymap
# - map
# - replace

# %%
dp2['email'].apply(len)
# Out:
# 0    5
# 1    6
# 2    9
# Name: email, dtype: int64

# %%
dp2['email'] = dp2['email'].apply(lambda x: x.lower())
dp2
# Out:
#       first   last      email
# 0    sohaib  awais      ahmad
# 1  talha123  talha     mumtaz
# 2  saleh123  saleh  jahanzaib

# %%
print(dp2.apply(pd.Series.max), end='\n.....................\n') #applies function to all series
print(dp2.apply(pd.Series.min))
# Out:
# first    talha123
# last        talha
# email      mumtaz
# dtype: object
# .....................
# first    saleh123
# last        awais
# email       ahmad
# dtype: object

# %%
dp2.applymap(len)
# Out:
#    first  last  email
# 0      6     5      5
# 1      8     5      6
# 2      8     5      9

# %%
dp2['first'].map({'awais':'sohaib'})
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# Name: first, dtype: object

# %%
dp2['first'].replace({'awais':'sohaib'})
# Out:
# 0      sohaib
# 1    talha123
# 2    saleh123
# Name: first, dtype: object

# %% [markdown]
# # Tutorial #6

# %%
dp2['full_name'] = dp2['first'] + " " + dp2['last']

# %%
dp2
# Out:
#       first   last      email       full_name
# 0    sohaib  awais      ahmad    sohaib awais
# 1  talha123  talha     mumtaz  talha123 talha
# 2  saleh123  saleh  jahanzaib  saleh123 saleh

# %%
dp2.drop(columns=['first','last'],inplace=True)
dp2
# Out:
#        email       full_name
# 0      ahmad    sohaib awais
# 1     mumtaz  talha123 talha
# 2  jahanzaib  saleh123 saleh

# %%
dp2[['first','last']] = dp2['full_name'].str.split(' ', expand=True)
dp2
# Out:
#        email       full_name     first   last
# 0      ahmad    sohaib awais    sohaib  awais
# 1     mumtaz  talha123 talha  talha123  talha
# 2  jahanzaib  saleh123 saleh  saleh123  saleh

# %%
filt = (dp2['last'].apply(len)==5 )| (dp2['last'].apply(len)==6)
dp2.drop(index=dp2[filt].index)
# Out:
# Empty DataFrame
# Columns: [email, full_name, first, last]
# Index: []

# %% [markdown]
# # Tutorial#7

# %%
dp2.sort_values(by='last')
# Out:
#        email       full_name     first   last
# 0      ahmad    sohaib awais    sohaib  awais
# 2  jahanzaib  saleh123 saleh  saleh123  saleh
# 1     mumtaz  talha123 talha  talha123  talha

# %%
# if 'last'(descending) is same then go for 'first'(ascending)
dp2.sort_values(by=['last','first'],ascending=[False,True], inplace=True)

# %%
dp2
# Out:
#        email       full_name     first   last
# 1     mumtaz  talha123 talha  talha123  talha
# 2  jahanzaib  saleh123 saleh  saleh123  saleh
# 0      ahmad    sohaib awais    sohaib  awais

# %%
dp2.sort_index(inplace=True)

# %%
dp2['first'].sort_values()     #Individual column sort
# Out:
# 2    saleh123
# 0      sohaib
# 1    talha123
# Name: first, dtype: object

# %% [markdown]
# # Stack Overflow

# %%
filt = (df['Country'].str.contains('Pak', na=False)) & df['CompFreq'].str.contains('Yearly', na=False)
df.loc[filt,['CompTotal','CompFreq','Currency']].sort_values(by=['CompTotal'],ascending=[False])
# Out:
#              CompTotal CompFreq                   Currency
# ResponseId
# 16546       10000000.0   Yearly       PKR\tPakistani rupee
# 47896        9000000.0   Yearly       PKR\tPakistani rupee
# 72909        6000000.0   Yearly       PKR\tPakistani rupee
# 4728         5720000.0   Yearly       PKR\tPakistani rupee
# 8366         5000000.0   Yearly       PKR\tPakistani rupee
# 62437        4000000.0   Yearly       PKR\tPakistani rupee
# 60083        3600000.0   Yearly       PKR\tPakistani rupee
# 8016         3500000.0   Yearly       PKR\tPakistani rupee
# 62325        2640000.0   Yearly       PKR\tPakistani rupee
# 6949         2500000.0   Yearly       PKR\tPakistani rupee
# 62432        2080000.0   Yearly       PKR\tPakistani rupee
# 9170         1600000.0   Yearly       PKR\tPakistani rupee
# 27397        1200000.0   Yearly       PKR\tPakistani rupee
# 67561        1190000.0   Yearly       PKR\tPakistani rupee
# 9050         1100000.0   Yearly       PKR\tPakistani rupee
# ...

# %%
filt = df['Currency'].str.contains('USD', na=False)
df.loc[filt,['Employment','EdLevel','YearsCode','YearsCodePro','DevType','CompTotal','CompFreq','LanguageHaveWorkedWith','Ethnicity']].nlargest(100,'CompTotal')
# Out:
#                                                    Employment  \
# ResponseId
# 3069                                      Employed, full-time
# 31191                                     Employed, full-time
# 71604                                     Employed, part-time
# 62108       Employed, full-time;Independent contractor, fr...
# 44886                                     Employed, full-time
# 1889        Independent contractor, freelancer, or self-em...
# 118         Employed, full-time;Independent contractor, fr...
# 14370                                     Employed, full-time
# 32447                                     Employed, full-time
# 24477                                     Employed, full-time
# 68515                                     Employed, full-time
# 50535                                     Employed, full-time
# 1941                                      Employed, full-time
# 30328                                     Employed, full-time
# ...

# %%
df.loc[40305]
# Out:
# MainBranch                                           I am a developer by profession
# Employment                        Independent contractor, freelancer, or self-em...
# RemoteWork                                                           Full in-person
# CodingActivities                                            Freelance/contract work
# EdLevel                           Secondary school (e.g. American high school, G...
# LearnCode                         Other online resources (e.g., videos, blogs, f...
# LearnCodeOnline                   Blogs;Stack Overflow;Online books;Video-based ...
# LearnCodeCoursesCert                                                            NaN
# YearsCode                                                          Less than 1 year
# YearsCodePro                                                                      2
# DevType                           Engineer, data;Engineer, site reliability;Deve...
# ...

# %%
df.nlargest(10,'CompTotal')
# Out:
#                                                    MainBranch  \
# ResponseId
# 35787                          I am a developer by profession
# 3069                           I am a developer by profession
# 70598                          I am a developer by profession
# 17568                          I am a developer by profession
# 19245       I am not primarily a developer, but I write co...
# 24641                          I am a developer by profession
# 31191                          I am a developer by profession
# 71604                          I am a developer by profession
# 34412                          I am a developer by profession
# 49875                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 35787                 Employed, full-time;Employed, part-time
# 3069                                      Employed, full-time
# 70598       Independent contractor, freelancer, or self-em...
# ...

# %% [markdown]
# # Tutorial#8

# %%
df['CompTotal'].median()    # Middle value of sorted array
# Out:
# 77500.0

# %%
df['CompTotal'].mean()  # Mean is biased towards the highest or the lowest value in dataset
# Out:
# 2.342434022174796e+52

# %%
df['Ethnicity'].count() #number of non-NA rows
# Out:
# 69474

# %%
cg = df.groupby('Country')

# %%
cg.get_group('Pakistan')['Ethnicity']
# Out:
# ResponseId
# 917                    Asian
# 1199             South Asian
# 1391         Southeast Asian
# 2918     Asian;Central Asian
# 3045         Southeast Asian
#                 ...
# 72825            South Asian
# 72869            South Asian
# 72909      Asian;South Asian
# 72938      Asian;South Asian
# 73029            South Asian
# Name: Ethnicity, Length: 711, dtype: object

# %%
cg['Sexuality'].value_counts(normalize=True).loc['Pakistan']
# Out:
# Sexuality
# Straight / Heterosexual                            0.768274
# Prefer not to say                                  0.149300
# Bisexual                                           0.035770
# Prefer to self-describe:                           0.029549
# Gay or Lesbian                                     0.004666
# Queer                                              0.004666
# Bisexual;Gay or Lesbian                            0.001555
# Bisexual;Prefer to self-describe:                  0.001555
# Bisexual;Queer                                     0.001555
# Bisexual;Straight / Heterosexual                   0.001555
# Bisexual;Straight / Heterosexual;Gay or Lesbian    0.001555
# Name: proportion, dtype: float64

# %%
cg['CompTotal'].median().loc['Pakistan']
# Out:
# 100000.0

# %%
cg['CompTotal'].median()
# Out:
# Country
# Afghanistan                                                  6000.0
# Albania                                                      5500.0
# Algeria                                                     75000.0
# Andorra                                                     31500.0
# Angola                                                     600000.0
# Antigua and Barbuda                                             NaN
# Argentina                                                  110000.0
# Armenia                                                    632500.0
# Australia                                                  125000.0
# Austria                                                     49750.0
# Azerbaijan                                                   3500.0
# Bahamas                                                         NaN
# Bahrain                                                      2865.0
# Bangladesh                                                  60000.0
# ...

# %%
cg['CompTotal'].agg(['median','mean'])      #apply multiple aggregate functions
# Out:
#                                                          median          mean
# Country
# Afghanistan                                              6000.0  3.808414e+06
# Albania                                                  5500.0  5.104657e+05
# Algeria                                                 75000.0  8.754444e+04
# Andorra                                                 31500.0  7.677250e+04
# Angola                                                 600000.0  1.287990e+09
# Antigua and Barbuda                                         NaN           NaN
# Argentina                                              110000.0  3.983275e+05
# Armenia                                                632500.0  1.387942e+06
# Australia                                              125000.0  3.719887e+05
# Austria                                                 49750.0  4.824716e+04
# Azerbaijan                                               3500.0  7.081739e+03
# ...

# %%
cg['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').mean())
# Out:
# Country
# Afghanistan                                             0.390625
# Albania                                                 0.339286
# Algeria                                                 0.527778
# Andorra                                                 0.266667
# Angola                                                  0.272727
# Antigua and Barbuda                                     0.000000
# Argentina                                               0.352250
# Armenia                                                 0.483516
# Australia                                               0.486207
# Austria                                                 0.462740
# Azerbaijan                                              0.492754
# Bahamas                                                 0.250000
# Bahrain                                                 0.428571
# Bangladesh                                              0.420000
# ...

# %% [markdown]
# # Tutorial#9

# %%
import numpy as np
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

df2 = pd.DataFrame(people)

# %%
df2.dropna(axis='index', how='any')      # is same as df.dropna()
# axis='index' drops rows if found any na
# axis='column' drops column if found any na
# how='all' drops only when all the values of the cells are missing
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df2.dropna(axis='index', how='any', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
#drop if any of subset columns are missing
df2.dropna(axis='index', how='any', subset=['last','email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
#drop if all of subset columns are missing
df2.dropna(axis='index', how='all', subset=['last','email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df2.replace('NA', np.nan, inplace=True)
df2.replace('Missing', np.nan, inplace=True)

# %%
df2.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df2.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df2.fillna('MISSINGG', inplace=False)
# Out:
#       first      last                    email       age
# 0     Corey   Schafer  CoreyMSchafer@gmail.com        33
# 1      Jane       Doe        JaneDoe@email.com        55
# 2      John       Doe        JohnDoe@email.com        63
# 3     Chris   Schafer                 MISSINGG        36
# 4  MISSINGG  MISSINGG                 MISSINGG  MISSINGG
# 5  MISSINGG  MISSINGG      Anonymous@email.com  MISSINGG
# 6  MISSINGG  MISSINGG                 MISSINGG  MISSINGG

# %%
df2['age'] = df2['age'].astype(float)

# %%
df2['age'].mean()
# Out:
# 46.75

# %%
# To treat missing values in cssv file as na values:
df = pd.read_csv('data/survey_results_public.csv', na_values=['Missing', 'NA'])
sdf = pd.read_csv('data/survey_results_schema.csv', na_values=['Missing', 'NA'])

# %%
df['YearsCode'].head()
# Out:
# 0    NaN
# 1    NaN
# 2     14
# 3     20
# 4      8
# Name: YearsCode, dtype: object

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# File /mnt/e/repos/ml/.venv/lib/python3.8/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File /mnt/e/repos/ml/.venv/lib/python3.8/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
# ...

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '14', '20', '8', '15', '3', '1', '6', '37', '5', '12', '22',
#        '11', '4', '7', '13', '36', '2', '25', '10', '40', '16', '27',
#        '24', '19', '9', '17', '18', '26', 'More than 50 years', '29',
#        '30', '32', 'Less than 1 year', '48', '45', '38', '39', '28', '23',
#        '43', '21', '41', '35', '50', '33', '31', '34', '46', '44', '42',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.251307285752338
